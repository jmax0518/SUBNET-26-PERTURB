# %% [markdown]
# # Perturb Subnet — Colab GPU Benchmark
#
# Run this notebook on **Runtime → T4 GPU**.
#
# Re-run **Cell 1** at the start of every new Colab session (after disconnect).

# %%
# Cell 1 — Setup (run every new session)
import os

REPO = "/content/SUBNET-26-PERTURB"
REPO_URL = "https://github.com/jmax0518/SUBNET-26-PERTURB.git"

# !nvidia-smi

if not os.path.isdir(REPO):
    # !git clone {REPO_URL} {REPO}
else:
    # %cd {REPO}
    # !git pull

# %cd {REPO}

# !pip install -q torchvision pillow numpy bittensor
# !pip install -q -e .

import torch
print("CUDA:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "none")

# %%
# Cell 2 — Verify attack module loads
from perturbnet.model import load_efficientnet_v2_l
from perturbnet.attack import run_quality_linf_attack

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = load_efficientnet_v2_l(device)
print("Model + attack module OK on", device)

# %%
# Cell 3 — Single-image benchmark
# !python scripts/test_miner_forward.py --image-path assets/dog_1.jpg

# %%
# Cell 4 — Batch benchmark (requires assets/test_images/ on GitHub)
# !python scripts/test_miner_forward.py --image-dir assets/test_images

# %%
# Cell 5 — Optional: save perturbed outputs and download
from google.colab import files

# !python scripts/test_miner_forward.py \
  --image-path assets/dog_1.jpg \
  --save-output-dir /content/attack_outputs

# !zip -r /content/attack_outputs.zip /content/attack_outputs
files.download("/content/attack_outputs.zip")

# %% [markdown]
# ## Optional: persist repo on Google Drive
#
# Uncomment and run once to avoid re-cloning after disconnect:
#
# ```python
# from google.colab import drive
# drive.mount('/content/drive')
#
# REPO = '/content/drive/MyDrive/SUBNET-26-PERTURB'
# # first time: !git clone https://github.com/jmax0518/SUBNET-26-PERTURB.git {REPO}
# %cd {REPO}
# !git pull
# !pip install -q -e .
# ```
